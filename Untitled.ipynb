# %%
import csv
import functools
import os
import re
import typing

import contextily
import geopandas
import pandas
import requests
import shapely.geometry
import tqdm.auto as tqdm
from matplotlib import pyplot

T_DataFrame = pandas.core.frame.DataFrame
tqdm.tqdm.pandas()
# Out:
# /home/leaf/miniconda3/lib/python3.7/site-packages/tqdm/std.py:668: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel

# %% [markdown]
# # 1. Download latest NYC 311 data from NYC OpenData
#
# **NOTE**: this is a very large file - 13.2GiB as of 2020-07-23. Extra documentation concerning field descriptors and other ways of interacting with the data can be found on [the official page](https://nycopendata.socrata.com/Social-Services/311-Service-Requests-from-2010-to-Present/erm2-nwe9).

# %%
NYC_311_URL = "https://nycopendata.socrata.com/api/views/erm2-nwe9/rows.csv?accessType=DOWNLOAD"
NYC_311_RAW_DATA = "nyc311.csv"
NYC_311_TRIMMED_DATA = "nyc311-fireworks.csv"

NYC_311_DOCS_URL = "https://nycopendata.socrata.com/api/views/erm2-nwe9/files/68b25fbb-9d30-486a-a571-7115f54911cd?download=true&filename=311_SR_Data_Dictionary_2018.xlsx"
NYC_311_DOCS = "data-dictionary.xlsx"

REQUESTS_CHUNK_SIZE = 4096

# %%
if not os.path.isfile(NYC_311_RAW_DATA):
    temp_path = NYC_RAW_DATA + ".part"
    response = requests.get(NYC_311_URL, stream=True)
    response.raise_for_status()
    progress = tqdm.tqdm(
        # 12.3e9iB is the estimated size, just to get a rough idea of download time
        total=int(response.headers.get("content-length", 13.2e9)),
        unit="iB",
        unit_scale=True
    )

    with open(temp_path, "wb") as output_fp:
        for chunk in response.iter_content(REQUESTS_CHUNK_SIZE):
            progress.update(len(chunk))
            output_fp.write(chunk)

    progress.close()
    os.rename(temp_path, NYC_311_RAW_DATA)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=12300000000.0), HTML(value='')))

# %%
if not os.path.isfile(NYC_311_DOCS):
    response = requests.get(NYC_311_DOCS_URL)
    response.raise_for_status()
    with open(NYC_311_DOCS, "wb") as output_fp:
        output_fp.write(response.content)

# %% [markdown]
# # 2. Filter out fireworks incidents
# \>12GB is far too much for a normal computer to be able to process without resorting to out-of-core processing methods. However, the number of 311 calls dealing with fireworks is likely to be a very small fraction of this, so we can do some filtering to make the data more manageable.

# %%
# we could use a streaming csv or pandas solution, but using a compiled regular
# expression is likely to be far faster
RE_FIREWORKS = re.compile(r"fireworks\s*", re.IGNORECASE)

# %%
if not os.path.isfile(NYC_311_TRIMMED_DATA):
    temp_path = NYC_311_TRIMMED_DATA + ".part"
    
    with open(NYC_311_RAW_DATA, "r") as input_fp,\
    open(temp_path, "w") as output_fp:
        # write out header
        output_fp.write(input_fp.readline())
        
        # filter out remaining rows
        # ~23.1M rows according to the dashboard, again to estimate time
        for line in tqdm.tqdm(
                input_fp,
                total=23.1e6,
                unit=" rows",
                unit_scale=True
            ):
            if RE_FIREWORKS.search(line):
                output_fp.write(line)
                
    os.rename(temp_path, NYC_311_TRIMMED_DATA)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=23100000.0), HTML(value='')))

# %% [markdown]
# # 3. Data cleanup, exploration, type conversions, etc

# %%
df_311 = pandas.read_csv(NYC_311_TRIMMED_DATA)
df_311.sample(5)
# Out:
#        Unique Key            Created Date             Closed Date Agency  \
# 1747     23537445  07/02/2012 10:52:05 PM  07/03/2012 12:22:20 AM   NYPD
# 12061    46566398  06/21/2020 11:21:55 PM  06/21/2020 11:25:11 PM   NYPD
# 12541    46570925  06/21/2020 11:58:57 PM  06/22/2020 12:40:40 AM   NYPD
# 13444    46574610  06/21/2020 10:21:58 PM  06/21/2020 10:24:55 PM   NYPD
# 3450     46504226  06/16/2020 11:08:22 PM  06/16/2020 11:13:55 PM   NYPD
#
#                            Agency Name     Complaint Type  Descriptor  \
# 1747   New York City Police Department  Illegal Fireworks         NaN
# 12061  New York City Police Department  Illegal Fireworks         NaN
# 12541  New York City Police Department  Illegal Fireworks         NaN
# 13444  New York City Police Department  Illegal Fireworks         NaN
# 3450   New York City Police Department  Illegal Fireworks         NaN
#
#          Location Type  Incident Zip        Incident Address  ...  \
# 1747   Street/Sidewalk       10032.0     547 WEST 157 STREET  ...
# 12061  Street/Sidewalk       11368.0  105-16 MARTENSE AVENUE  ...
# 12541  Street/Sidewalk       10028.0                2 AVENUE  ...
# 13444  Street/Sidewalk       10032.0   2075 AMSTERDAM AVENUE  ...
# 3450   Street/Sidewalk       10031.0    561 WEST  149 STREET  ...
#
#       Vehicle Type Taxi Company Borough Taxi Pick Up Location  \
# 1747           NaN                  NaN                   NaN
# 12061          NaN                  NaN                   NaN
# 12541          NaN                  NaN                   NaN
# 13444          NaN                  NaN                   NaN
# 3450           NaN                  NaN                   NaN
#
#       Bridge Highway Name Bridge Highway Direction Road Ramp  \
# 1747                  NaN                      NaN       NaN
# 12061                 NaN                      NaN       NaN
# 12541                 NaN                      NaN       NaN
# 13444                 NaN                      NaN       NaN
# 3450                  NaN                      NaN       NaN
#
#       Bridge Highway Segment   Latitude  Longitude  \
# 1747                     NaN  40.833423 -73.943345
# 12061                    NaN  40.741510 -73.855024
# 12541                    NaN  40.776562 -73.952705
# 13444                    NaN  40.836293 -73.939515
# 3450                     NaN  40.828452 -73.947331
#
#                                        Location
# 1747    (40.83342349076293, -73.94334465483017)
# 12061    (40.74151016971833, -73.8550240622884)
# 12541   (40.77656249549855, -73.95270476776597)
# 13444   (40.83629251462459, -73.93951515416573)
# 3450   (40.828451959095986, -73.94733087120245)
#
# [5 rows x 41 columns]

# %%
def sample_not_null(df: T_DataFrame, column: str) -> typing.Any:
    subset = df_311[column]
    if len(subset) > 0:
        return subset.sample(1).iloc[0]

functools.reduce(
    lambda left, right: pandas.merge(
        left, right, left_index=True, right_index=True
    ),
    [
        
        # official documentation
        pandas.read_excel(NYC_311_DOCS, sheet_name="Data Dictionary")\
            .set_index("Column Name")[["Description", "Expected Values"]],
        
        # data types
        df_311.dtypes.rename("dtype"),
        
        # coverage
        (df_311.isnull().sum() / len(df_311)).rename("percent_null"),
        
        # sample data
        pandas.Series(df_311.columns, index=df_311.columns)\
            .apply(lambda column: sample_not_null(df_311, column))\
            .rename("sample"),
    ]
).fillna("") # just to clean up the output
# Out:
#                                                                       Description  \
# Unique Key                      Unique identifier of a Service Request (SR) in...
# Created Date                                                 Date SR  was created
# Closed Date                               Date SR was closed by responding agency
# Agency                               Acronym of responding City Government Agency
# Agency Name                     Full Agency name of responding City Government...
# Complaint Type                  This is the fist level of a hierarchy identify...
# Descriptor                      This is  associated to the Complaint Type, and...
# Status                                                    Status of SR submitted
# Due Date                        Date when responding agency is expected to upd...
# Resolution Action Updated Date   Date when responding agency last updated the SR.
# Resolution Description          Describes the last action taken on the SR by t...
# Location Type                   Describes the type of location used in the add...
# Incident Zip                    Incident location zip code, provided by geo va...
# Incident Address                House number of incident address provided by s...
# Street Name                     Street name of incident address provided by th...
# Cross Street 1                  First Cross street based on the geo validated ...
# Cross Street 2                  Second Cross Street based on the geo validated...
# Intersection Street 1           First intersecting street based on geo validat...
# Intersection Street 2           Second intersecting street based on geo valida...
# Address Type                     Type of incident location information available.
# City                            City of the incident location provided by geov...
# Landmark                        If the incident location is identified as a La...
# Facility Type                   If available, this field describes the type of...
# Community Board                                        Provided by geovalidation.
# BBL                             Borough Block and Lot, provided by geovalidati...
# Borough                         Provided by the submitter and confirmed by geo...
# X Coordinate (State Plane)      Geo validated, X coordinate of the incident lo...
# Y Coordinate (State Plane)      Geo validated,  Y coordinate of the incident l...
# Latitude                                   Geo based Lat of the incident location
# Longitude                                 Geo based Long of the incident location
# Location                        Combination of the geo based lat & long of the...
# Park Facility Name              If the incident location is a Parks Dept facil...
# Park Borough                    The borough of incident if it is a Parks Dept ...
# Vehicle Type                    If the incident is a taxi, this field describe...
# Taxi Company Borough            If the incident is identified as a taxi, this ...
# Taxi Pick Up Location           If the incident is identified as a taxi, this ...
# Bridge Highway Name             If the incident is identified as a Bridge/High...
# Bridge Highway Direction        If the incident is identified as a Bridge/High...
# Road Ramp                       If the incident location was Bridge/Highway th...
# Bridge Highway Segment          Additional information on the section of the B...
#
#                                                                   Expected Values  \
# Unique Key
# Created Date                               Date in format MM/DD/YY HH:MM:SS AM/PM
# Closed Date                                Date in format MM/DD/YY HH:MM:SS AM/PM
# Agency
# Agency Name
# Complaint Type
# Descriptor
# Status                                    Assigned, Cancelled, Closed, Pending, +
# Due Date                                   Date in format MM/DD/YY HH:MM:SS AM/PM
# Resolution Action Updated Date             Date in format MM/DD/YY HH:MM:SS AM/PM
# Resolution Description
# Location Type
# Incident Zip
# Incident Address
# Street Name
# Cross Street 1
# Cross Street 2
# Intersection Street 1
# Intersection Street 2
# Address Type                    Values: Address; Block face; Intersection; Lat...
# City
# Landmark
# Facility Type
# Community Board
# BBL
# Borough
# X Coordinate (State Plane)
# Y Coordinate (State Plane)
# Latitude
# Longitude
# Location
# Park Facility Name
# Park Borough
# Vehicle Type                                Car Service; Commuter Van; Green Taxi
# Taxi Company Borough
# Taxi Pick Up Location           Grand Central Station; Intersection; JKF Airpo...
# Bridge Highway Name
# Bridge Highway Direction
# Road Ramp                                                           Roadway; Ramp
# Bridge Highway Segment
#
#                                   dtype  percent_null  \
# Unique Key                        int64      0.000000
# Created Date                     object      0.000000
# Closed Date                      object      0.016502
# Agency                           object      0.000000
# Agency Name                      object      0.000000
# Complaint Type                   object      0.000000
# Descriptor                      float64      1.000000
# Status                           object      0.000000
# Due Date                         object      0.862978
# Resolution Action Updated Date   object      0.015691
# Resolution Description           object      0.015691
# Location Type                    object      0.046598
# Incident Zip                    float64      0.001014
# Incident Address                 object      0.064115
# Street Name                      object      0.064115
# Cross Street 1                   object      0.063371
# Cross Street 2                   object      0.063371
# Intersection Street 1            object      0.073651
# Intersection Street 2            object      0.073651
# Address Type                     object      0.862978
# City                             object      0.122075
# Landmark                         object      0.258758
# Facility Type                    object      0.866698
# Community Board                  object      0.000000
# BBL                             float64      0.274111
# Borough                          object      0.000000
# X Coordinate (State Plane)      float64      0.011700
# Y Coordinate (State Plane)      float64      0.011700
# Latitude                        float64      0.011700
# Longitude                       float64      0.011700
# Location                         object      0.011700
# Park Facility Name               object      0.000000
# Park Borough                     object      0.000000
# Vehicle Type                    float64      1.000000
# Taxi Company Borough            float64      1.000000
# Taxi Pick Up Location           float64      1.000000
# Bridge Highway Name              object      0.999594
# Bridge Highway Direction         object      0.999256
# Road Ramp                        object      0.999256
# Bridge Highway Segment           object      0.999256
#
#                                                                            sample
# Unique Key                                                               17572496
# Created Date                                               06/17/2020 11:35:13 PM
# Closed Date                                                06/20/2020 05:04:22 AM
# Agency                                                                       NYPD
# Agency Name                                       New York City Police Department
# Complaint Type                                                  Illegal Fireworks
# Descriptor
# Status                                                                     Closed
# Due Date
# Resolution Action Updated Date                             05/26/2020 08:00:19 PM
# Resolution Description          This complaint does not fall under the Police ...
# Location Type                                                     Street/Sidewalk
# Incident Zip                                                                10456
# Incident Address                                                  826 BECK STREET
# Street Name                                                            174 STREET
# Cross Street 1                                                         137 AVENUE
# Cross Street 2                                                               BEND
# Intersection Street 1                                               ROGERS AVENUE
# Intersection Street 2                                FRANKLIN AVENUE SHUTTLE LINE
# Address Type
# City                                                                     BROOKLYN
# Landmark                                                         EAST  166 STREET
# Facility Type
# Community Board                                                       09 BROOKLYN
# BBL                                                                   1.02081e+09
# Borough                                                                  BROOKLYN
# X Coordinate (State Plane)                                                 999845
# Y Coordinate (State Plane)                                                 208082
# Latitude                                                                  40.8545
# Longitude                                                                -73.9634
# Location                                  (40.64579767844507, -73.96335217736032)
# Park Facility Name                                                    Unspecified
# Park Borough                                                             BROOKLYN
# Vehicle Type
# Taxi Company Borough
# Taxi Pick Up Location
# Bridge Highway Name
# Bridge Highway Direction
# Road Ramp
# Bridge Highway Segment

# %% [markdown]
# Just to verify that we only have firework complaints here:

# %%
df_311["Complaint Type"].value_counts()
# Out:
# Illegal Fireworks    14786
# Name: Complaint Type, dtype: int64

# %% [markdown]
# There are about 1.17% of reports without a geocoded lat-lon; is there a listed location that we can use to geocode?

# %%
print(df_311["Incident Address"][df_311["Location"].isnull()].dropna().to_list())
# Out:
# ['WEST  176 STREET', '1 AVENUE', 'CLIFFSIDE AVENUE', 'CLEVELAND STREET', 'WEST   11 STREET', 'WEST  141 STREET', 'WALTON AVENUE', '58 AVENUE', '83 STREET', '144 STREET', '57 DRIVE', 'UNION STREET', 'EAST 110 STREET', '61 STREET', 'WEST 176 STREET', 'WEST 135 STREET', 'EAST 102 STREET', 'EAST 26 STREET', 'LASALLE STREET', 'WEST 17 STREET', 'WEST 133 STREET', 'WEST  100 STREET', 'LENOX AVENUE', 'HART STREET', 'WEST  100 STREET', 'BERRY STREET', 'WEST 135 STREET', 'BOYNTON AVENUE', 'WEST   55 STREET', 'WEST 129 STREET', 'WEST 115 STREET', 'TAPSCOTT STREET', 'EAST 112 STREET', 'JOHNSON AVENUE', 'LAFAYETTE AVENUE', '41 ROAD', 'WEST 136 STREET', 'CHELSEA ROAD', 'EAST  160 STREET', 'ALVERSON AVENUE', 'WEST  175 STREET', 'CLARKSON AVENUE', 'COLLEGE AVENUE', 'EAST   19 STREET', 'MILFORD STREET', 'EAST   18 STREET', 'TOWNSEND AVENUE', 'WEST  143 STREET', 'SHERMAN AVENUE', 'AUDUBON AVENUE', 'LENOX ROAD', 'BALTIC STREET', 'BERGEN STREET', 'LINCOLN PLACE', 'DEAN STREET', 'AVENUE D', 'STERLING PLACE', 'WEST  172 STREET', 'EAST    7 STREET', 'PRESIDENT STREET', '8 AVENUE', 'WEST  139 STREET', 'EMPIRE BOULEVARD', 'SOUTH    1 STREET', 'WEST  129 STREET', 'WINTHROP STREET', 'WEST  174 STREET', '82 STREET', 'WEST  109 STREET', 'EAST  211 STREET', 'BEACH   63 STREET', 'HERKIMER STREET', 'EAST   35 STREET', 'EAST   21 STREET', 'EAST   19 STREET', 'EAST  231 STREET', 'NOSTRAND AVENUE', '3 AVENUE', 'VERMILYEA AVENUE', 'BRONX BOULEVARD', 'EAST  206 STREET', 'EAST   53 STREET', 'WEST  139 STREET', 'WEST  139 STREET', 'DAVIDSON AVENUE', 'LEFFERTS AVENUE', 'WEST  122 STREET', 'UNION STREET', 'EAST   85 STREET', '107 AVENUE', 'PARK AVENUE', 'EAST   80 STREET', 'WEST  147 STREET', 'EAST   51 STREET', 'EAST  212 STREET', 'MINNA STREET', 'EAST   14 STREET', 'EAST   57 STREET', '2 AVENUE', 'WEST  189 STREET', 'BRONX BOULEVARD', 'SAINT NICHOLAS AVENUE', 'EAST  105 STREET', 'AVENUE H', 'EAST  107 STREET', 'AMSTERDAM AVENUE', 'HAWTHORNE STREET', 'BRONX BOULEVARD', 'EMPIRE BOULEVARD', 'AVENUE L', 'EAST   99 STREET', 'EAST   98 STREET', 'CLARKSON AVENUE', '24 STREET', 'OCEAN AVENUE', 'LINCOLN ROAD', '42 STREET', '76 STREET', 'AVENUE X', 'WEST  139 STREET', '252 STREET', 'WEST   25 STREET', 'MARCUS GARVEY BOULEVARD', 'WEST  139 STREET', 'GLENWOOD ROAD', 'EAST   95 STREET', 'EAST  175 STREET', '161 STREET', '62 AVENUE', 'WEST  107 STREET', 'WEST   12 STREET', 'NERO AVENUE', 'WHITE PLAINS ROAD', '1 AVENUE', 'HUGUENOT AVENUE', 'HANCOCK STREET', 'WEST 50 STREET', 'WEST 90 STREET', 'WEST 90 STREET']

# %% [markdown]
# It seems like the NYC geocoding team did a really good job; the non-geocoded locations don't seem like they can be geocoded very easily. We have plenty of data so we can just drop these for the analysis.
#
# From the above, it seems that only a few columns will be relevant, so let's go ahead and subset them now, as well as add some spatial types:

# %%
df_311 = df_311[[
    "Created Date", "Closed Date", # datetime variables
    "Incident Zip", "City", "Borough", # locations IDs, for standard joining
    "Longitude", "Latitude",  # WGS84 coords, for geospatial joining and viz
]]

# spatial types
df_311["geometry"] = df_311[["Longitude", "Latitude"]]\
    .apply(shapely.geometry.Point, axis=1)
gdf_311 = geopandas.GeoDataFrame(df_311)
gdf_311.crs = {"init": "epsg:4326"}

# transform to web mercator for more convenient plotting
gdf_311 = gdf_311.to_crs({"init": "epsg:3857"})

# %%
(figure, axis) = pyplot.subplots(figsize=(7, 7))
gdf_311.plot(ax=axis, markersize=1, alpha=0.1)
axis.set_xticks([])
axis.set_yticks([])
contextily.add_basemap(ax=axis, source=contextily.providers.CartoDB.Positron)
pyplot.show()

# %% [markdown]
# # 4. Analysis
# Right away, we can see very large concentrations of complaints in central Brooklyn and the Northern part of Manhattan. Are there any significant patterns, either temporally or spatially?
